# %%
import pandas as pd

# %%
emprestimo_20101 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv')
emprestimo_20102 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv')
emprestimo_20111 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv')
emprestimo_20112 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv')
emprestimo_20121 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv')
emprestimo_20122 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv')
emprestimo_20131 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv')
emprestimo_20132 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv')
emprestimo_20141 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv')
emprestimo_20142 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv')
emprestimo_20151 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv')
emprestimo_20152 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv')
emprestimo_20161 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv')
emprestimo_20162 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv')
emprestimo_20171 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv')
emprestimo_20172 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv')
emprestimo_20181 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv')
emprestimo_20182 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv')
emprestimo_20191 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv')
emprestimo_20192 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv')
emprestimo_20201 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv')

# %%
emprestimo_combinado = pd.concat([emprestimo_20101, emprestimo_20102, emprestimo_20111, emprestimo_20112,
                                  emprestimo_20121, emprestimo_20122, emprestimo_20131, emprestimo_20132,
                                  emprestimo_20141, emprestimo_20142, emprestimo_20151, emprestimo_20152,
                                  emprestimo_20161, emprestimo_20162, emprestimo_20171, emprestimo_20172,
                                  emprestimo_20181, emprestimo_20182, emprestimo_20191, emprestimo_20192,
                                  emprestimo_20201], axis=0)

# %%
emprestimo_combinado
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 0             709684       L095049                            NaN
# 1             709685       L167050                            NaN
# 2             709686    2006017618  2010/01/26 08:07:01.738000000
# 3             709687       L184117  2010/01/18 11:07:46.470000000
# 4             709684       L095049                            NaN
# ...              ...           ...                            ...
# 26556        2989086    2008047044                            NaN
# 26557        2989087    2008047047                            NaN
# 26558        2989088    2010052905                            NaN
# 26559        2989089    2010048023                            NaN
# 26560        2989090    2013106838                            NaN
#
#                      data_emprestimo                 data_devolucao  \
# 0      2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimo_sem_nan = emprestimo_combinado.dropna()
emprestimo_sem_nan
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 2             709686    2006017618  2010/01/26 08:07:01.738000000
# 3             709687       L184117  2010/01/18 11:07:46.470000000
# 6             709686    2006017618  2010/01/26 08:07:01.738000000
# 7             709687       L184117  2010/01/18 11:07:46.470000000
# 8             709688    2007027500  2010/01/19 15:59:26.464000000
# ...              ...           ...                            ...
# 26468        2988998    2010084076  2020/04/27 23:27:14.132000000
# 26469        2988999    2011024982  2020/04/27 23:27:14.108000000
# 26477        2989007    2014069838  2020/03/23 10:42:38.432000000
# 26510        2989040    2016025770  2020/04/01 22:25:43.652000000
# 26534        2989064       S023116  2021/07/19 16:17:24.750000000
#
#                      data_emprestimo                 data_devolucao  \
# 2      2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...

# %%
emprestimos = emprestimo_sem_nan.drop_duplicates()
emprestimos
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 2             709686    2006017618  2010/01/26 08:07:01.738000000
# 3             709687       L184117  2010/01/18 11:07:46.470000000
# 8             709688    2007027500  2010/01/19 15:59:26.464000000
# 9             709689       L157395  2010/01/19 15:59:26.447000000
# 11            709691    2008046357  2010/01/19 11:50:13.404000000
# ...              ...           ...                            ...
# 26468        2988998    2010084076  2020/04/27 23:27:14.132000000
# 26469        2988999    2011024982  2020/04/27 23:27:14.108000000
# 26477        2989007    2014069838  2020/03/23 10:42:38.432000000
# 26510        2989040    2016025770  2020/04/01 22:25:43.652000000
# 26534        2989064       S023116  2021/07/19 16:17:24.750000000
#
#                      data_emprestimo                 data_devolucao  \
# 2      2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...

# %%
acervo = pd.read_parquet('./dados_exemplares.parquet')
acervo
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
acervo_sem_nan = acervo.dropna()
acervo_sem_nan
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
acervos = acervo_sem_nan.drop_duplicates()
acervos
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
emprestimos
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 2             709686    2006017618  2010/01/26 08:07:01.738000000
# 3             709687       L184117  2010/01/18 11:07:46.470000000
# 8             709688    2007027500  2010/01/19 15:59:26.464000000
# 9             709689       L157395  2010/01/19 15:59:26.447000000
# 11            709691    2008046357  2010/01/19 11:50:13.404000000
# ...              ...           ...                            ...
# 26468        2988998    2010084076  2020/04/27 23:27:14.132000000
# 26469        2988999    2011024982  2020/04/27 23:27:14.108000000
# 26477        2989007    2014069838  2020/03/23 10:42:38.432000000
# 26510        2989040    2016025770  2020/04/01 22:25:43.652000000
# 26534        2989064       S023116  2021/07/19 16:17:24.750000000
#
#                      data_emprestimo                 data_devolucao  \
# 2      2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...

# %%
acervos
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
df_mesclado = pd.merge(emprestimos, acervos, on='codigo_barras', how='inner')
df_mesclado
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 0              709686    2006017618  2010/01/26 08:07:01.738000000
# 1              749227    2006017618  2010/04/19 17:35:25.987000000
# 2             1175444    2006017618  2012/03/11 17:05:30.982000000
# 3             1209694    2006017618  2012/04/11 12:34:59.458000000
# 4             1374962    2006017618  2012/12/12 07:40:40.406000000
# ...               ...           ...                            ...
# 906407        2988812    2016019436  2020/04/26 11:43:40.062000000
# 906408        2988874    2010080699  2021/08/10 02:30:14.871000000
# 906409        2988922    2018031109  2020/03/29 10:17:16.672000000
# 906410        2988968    2016033194  2020/04/06 18:21:57.168000000
# 906411        2989007    2014069838  2020/03/23 10:42:38.432000000
#
#                       data_emprestimo                 data_devolucao  \
# 0       2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...
